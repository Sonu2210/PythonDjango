# %%
"Q1."
s="Hey i am from New Delhi"
print(len(s))
list=s.split()
print(list)
# Out:
# 23
# ['Hey', 'i', 'am', 'from', 'New', 'Delhi']

# %%
"Q2."

s="name is rahul"
print(s.capitalize())
print(s.replace('n', 'R').title())
print(s.upper())
# Out:
# Name is rahul
# Rame Is Rahul
# NAME IS RAHUL

# %%
"Q3."
l=float(input("enter length : "))
b=float(input("enter breadth : "))
p=2*(l+b)
a=l*b
print("Perimeter = ",p)
print("Area = ",a)
# Out:
# enter length : 4
# enter breadth : 2
# Perimeter =  12.0
# Area =  8.0

# %%
"Q4."
d=float(input("Enter the diameter of the circle : "))
r=d/2
c=2*3.14*r
a=3.14*r*r
print("Circumference : ",c)
print("Area : ",a)
# Out:
# Enter the diameter of the circle : 10
# Circumference :  31.400000000000002
# Area :  78.5

# %%
"Q5."
import math
coeffa=float(input("Enter the coefficient a : "))
coeffb=float(input("Enter the coefficient b : "))
coeffc=float(input("Enter the coefficient c : "))
coeffd=float(input("Enter the coefficient d : "))
dis=math.sqrt((coeffb**2)-4*coeffc)
alpha=(-coeffb+dis)/2*coeffa
beta=(-coeffb-dis)/2*coeffa
print("The roots of the Quadratic eq. : ", "Alpha = ",alpha, "Beta = ",beta)
# Out:
# Enter the coefficient a : 2
# Enter the coefficient b : 8
# Enter the coefficient c : 4
# Enter the coefficient d : 6
# The roots of the Quadratic eq. :  Alpha =  -1.0717967697244912 Beta =  -14.928203230275509

# %%
"Q6" 
r=float(input("Enter the raidus : ")) 
v=round((4/3)*3.14*(r**3),3) 
print("Volume of sphere : ",v)
# Out:
# Enter the raidus : 22
# Volume of sphere :  44579.627

# %%
"Q7."
n=input("Enter the number : ")
if(n.isdigit()):
    print(len(n))
else:
    print("Enter number only")
# Out:
# Enter the number : 3454
# 4

# %%
"Q8."
str=input("Enter a string : ")
print(str.upper())
# Out:
# Enter a string : hey
# HEY

# %%
"Q9."
s=input("Enter a string : ")
n=int(input("Enter index NO. : "))
c=input("Enter a character : "))
if n<len(s):
    s=list(s)
    s[n]=c
else:
    print("Invalid")

# %%
"Q10."
str=("Enter a string")
print(str[::-1])
